# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests
import json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response  = r.text
data = json.loads(response)
#print(type(data))
rowLen = len(data)
print('一次會回傳' + str(rowLen) + '筆資料')
data[0]
# Out:
# 一次會回傳30筆資料
# {'id': 233858612,
#  'title': '天生長相',
#  'excerpt': '曾經是流浪貓的他，來我家。我就不要太多陳述，賞貓！，下台，謝謝各位，最近因為亂尿尿 我們只好...拿鈴鐺了',
#  'anonymousSchool': False,
#  'anonymousDepartment': False,
#  'pinned': False,
#  'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#  'replyId': None,
#  'createdAt': '2020-06-12T02:45:15.394Z',
#  'updatedAt': '2020-06-12T02:45:15.394Z',
#  'commentCount': 10,
#  'likeCount': 236,
#  'withNickname': True,
#  'tags': [],
#  'topics': ['貓', '可愛'],
#  'meta': {'layout': 'classic'},
#  'forumName': '寵物',
#  'forumAlias': 'pet',
#  'nsfw': False,
#  'gender': 'F',
#  'school': '有卡稱就有菊花 我是菊花',
#  'department': 'yx067618',
#  'replyTitle': None,
#  'mediaMeta': [{'id': 'badee57d-14e0-4a14-9e0d-4ac4cbf37c45',
#    'url': 'https://megapx-assets.dcard.tw/images/96afb71a-549c-40f7-9426-192c87058ae5/160.jpeg',
#    'normalizedUrl': 'https://megapx-assets.dcard.tw/images/96afb71a-549c-40f7-9426-192c87058ae5/160.jpeg',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/96afb71a-549c-40f7-9426-192c87058ae5/160.jpeg',
#    'type': 'image/thumbnail',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 120,
#    'height': 160},
#   {'id': 'badee57d-14e0-4a14-9e0d-4ac4cbf37c45',
#    'url': 'https://megapx-assets.dcard.tw/images/96afb71a-549c-40f7-9426-192c87058ae5/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/96afb71a-549c-40f7-9426-192c87058ae5',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/96afb71a-549c-40f7-9426-192c87058ae5/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1500,
#    'height': 2000},
#   {'id': '953f82c3-b855-4a80-9b6e-f7fa955d7e24',
#    'url': 'https://megapx-assets.dcard.tw/images/8909fba1-135d-4b02-aa62-40ba74d68488/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/8909fba1-135d-4b02-aa62-40ba74d68488',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/8909fba1-135d-4b02-aa62-40ba74d68488/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1500,
#    'height': 2000},
#   {'id': 'f34b0959-39f3-4849-9715-40165a387353',
#    'url': 'https://megapx-assets.dcard.tw/images/cb189413-5f9f-4a60-8452-760412b4bde7/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/cb189413-5f9f-4a60-8452-760412b4bde7',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/cb189413-5f9f-4a60-8452-760412b4bde7/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1500,
#    'height': 2000},
#   {'id': 'd72697d0-e4d4-46f8-9c39-29acda74ee0d',
#    'url': 'https://megapx-assets.dcard.tw/images/ca251617-1c0f-4a48-bdae-1171971fb2f8/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/ca251617-1c0f-4a48-bdae-1171971fb2f8',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/ca251617-1c0f-4a48-bdae-1171971fb2f8/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1499,
#    'height': 2000},
#   {'id': '3e046b99-97bf-4c07-9feb-8bd9b209b5ad',
#    'url': 'https://megapx-assets.dcard.tw/images/eb056b3a-9460-4e82-9190-4a7173c6e349/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/eb056b3a-9460-4e82-9190-4a7173c6e349',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/eb056b3a-9460-4e82-9190-4a7173c6e349/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1500,
#    'height': 2000},
#   {'id': 'b8238d89-d031-4c90-be45-b8a8c4d6cf6d',
#    'url': 'https://megapx-assets.dcard.tw/images/57d69a38-13aa-4c79-afb2-71c8d6ed4b3f/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/57d69a38-13aa-4c79-afb2-71c8d6ed4b3f',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images
160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 828,
#    'height': 1472},
#   {'id': 'a75ad9fb-f64f-496f-8af5-ea08ed302ccd',
#    'url': 'https://megapx-assets.dcard.tw/images/bdc668a8-9462-408e-8824-aa550886370c/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/bdc668a8-9462-408e-8824-aa550886370c',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/bdc668a8-9462-408e-8824-aa550886370c/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1125,
#    'height': 2000},
#   {'id': 'b04022f9-157a-4618-a912-e78cd8ecb604',
#    'url': 'https://megapx-assets.dcard.tw/images/303c3338-f6d7-4b57-8ec0-4a7c15e6c44c/640.jpeg',
#    'normalizedUrl': 'https://megapx.dcard.tw/v1/images/303c3338-f6d7-4b57-8ec0-4a7c15e6c44c',
#    'thumbnail': 'https://megapx-assets.dcard.tw/images/303c3338-f6d7-4b57-8ec0-4a7c15e6c44c/160.jpeg',
#    'type': 'image/megapx',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z',
#    'width': 1125,
#    'height': 2000},
#   {'id': 'c530b1ce-e432-4c62-941d-e83951e77530',
#    'url': 'https://www.dcard.tw/v2/vivid/videos/c6fe7ebd-d6f8-4692-88ac-07a85b2f3081?r=1.7777777777777777',
#    'normalizedUrl': '',
#    'thumbnail': 'https://vivid.dcard.tw/Public/c6fe7ebd-d6f8-4692-88ac-07a85b2f3081/thumbnail.jpg',
#    'type': 'video/vivid',
#    'tags': [],
#    'createdAt': '2020-06-12T02:45:15.394Z',
#    'updatedAt': '2020-06-12T02:45:15.394Z'}],
#  'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 235},
#   {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#  'hidden': False,
#  'customStyle': None,
#  'isSuspiciousAccount': False,
#  'layout': 'classic',
#  'withImages': True,
#  'withVideos': True,
#  'media': [{'url': 'https://megapx-assets.dcard.tw/images/96afb71a-549c-40f7-9426-192c87058ae5/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/8909fba1-135d-4b02-aa62-40ba74d68488/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/cb189413-5f9f-4a60-8452-760412b4bde7/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/ca251617-1c0f-4a48-bdae-1171971fb2f8/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/eb056b3a-9460-4e82-9190-4a7173c6e349/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/57d69a38-13aa-4c79-afb2-71c8d6ed4b3f/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/b24243e1-d193-4031-b472-fd3d51252c2f/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/5f0edc5d-242d-4bbd-9ca1-ff6151488894/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/b6d240c8-fdda-4899-a734-26efb0d06eb4/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/6b84eabb-25a2-4263-b749-7bbbc9ee9310/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/c95ef2ed-52fd-45c6-bf9f-49445f2a5320/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/aa039c82-8372-4583-8b03-1fe5b27b4d97/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/4d1f651f-eeb3-49bd-8dfd-c0bcf69466f2/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/b4a07267-e248-4986-b280-134b2a62eb01/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/c376a64f-a20f-4614-ae7c-cb7733656d3e/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/b3609448-67c1-4795-b57d-97b04a2ad763/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/bdc668a8-9462-408e-8824-aa550886370c/640.jpeg'},
#   {'url': 'https://megapx-assets.dcard.tw/images/303c3338-f6d7-4b57-8ec0-4a7c15e6c44c/640.jpeg'},
#   {'url': 'https://vivid.dcard.tw/Public/c6fe7ebd-d6f8-4692-88ac-07a85b2f3081/thumbnail.jpg'}],
#  'reportReasonText': '',
#  'postAvatar': ''}

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
rowDetail = []
total = []
for d in data:
    rowDetail = [d['title'],d['createdAt'],d['commentCount'],d['likeCount']]
    total.append(rowDetail)
    #print(d['title'],d['createdAt'],d['commentCount'],d['likeCount'])
total
# Out:
# [['天生長相', '2020-06-12T02:45:15.394Z', 10, 236],
#  ['貓咪送養', '2020-06-12T13:24:27.269Z', 10, 167],
#  ['#貓奴必備🐱主子的如廁小法寶✨五星級飯店的如廁體驗', '2020-06-12T07:01:17.329Z', 8, 149],
#  ['#更#⚠️急⚠️', '2020-06-11T22:58:32.042Z', 3, 116],
#  ['回覆義守大學同學的限時動態', '2020-06-11T16:45:32.978Z', 7, 78],
#  ['我🏠ㄉ🐹（圖多）', '2020-06-11T17:08:40.143Z', 23, 68],
#  ['#問 貓咪撥沙動作', '2020-06-12T04:27:35.849Z', 5, 24],
#  ['希望有好心人士可以領養小黑🐶', '2020-06-12T07:14:40.156Z', 0, 23],
#  ['這是我的貓 如果你已經看過', '2020-06-12T09:25:51.293Z', 0, 19],
#  ['我家的毛小孩2', '2020-06-12T13:03:59.513Z', 2, 14],
#  ['小貓一直跑上床', '2020-06-11T16:25:15.420Z', 8, 13],
#  ['轉：⚠️急⚠️', '2020-06-12T06:35:57.906Z', 0, 12],
#  ['愛看鏡頭的貓', '2020-06-12T02:47:08.026Z', 3, 11],
#  ['求領養 上班的地方發現的', '2020-06-12T17:12:39.764Z', 2, 10],
#  ['越養越懶的🐰', '2020-06-12T03:50:11.326Z', 1, 9],
#  ['倉鼠的眼睛受傷了🐹', '2020-06-12T14:33:22.037Z', 8, 5],
#  ['野貓在我家倉庫生了四個寶寶不知該如何是好', '2020-06-12T09:12:24.320Z', 4, 5],
#  ['沒有形象可言的喵', '2020-06-12T03:32:53.474Z', 1, 5],
#  ['一些小蜜袋鼯照片分享', '2020-06-12T17:53:34.345Z', 4, 4],
#  ['急！撿到班鳩幼鳥！教我怎麼救牠', '2020-06-11T17:36:33.469Z', 18, 4],
#  ['繼紐特後 再來看看家裡其他成員', '2020-06-12T15:11:44.618Z', 2, 2],
#  ['求各種混的神奇的米克斯', '2020-06-12T10:54:41.753Z', 0, 2],
#  ['兩喵的縮時攝影', '2020-06-12T07:36:11.359Z', 2, 2],
#  ['有這麼好睡嗎？', '2020-06-12T04:49:07.580Z', 1, 2],
#  ['半路上救下的小袋鼠', '2020-06-13T02:31:11.042Z', 0, 1],
#  ['長大了被刪文了只好再發一次', '2020-06-12T19:47:53.284Z', 1, 1],
#  ['加拿大貓奴請進', '2020-06-12T18:41:32.999Z', 0, 1],
#  ['狗怕癢嗎', '2020-06-12T15:59:54.006Z', 2, 1],
#  ['母狗寵物結紮醫院推薦🥺', '2020-06-12T06:11:40.500Z', 2, 1],
#  ['流浪動物攝影', '2020-06-12T04:09:04.835Z', 2, 1]]

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
def my_calculate(typeVal,url):
    commentCount = 0
    likeCount = 0
    r = requests.get(url)
    response  = r.text
    data = json.loads(response)
    for d in data:
        commentCount += d['commentCount']
        likeCount += d['likeCount']
    avgComment = commentCount/len(data)
    avgLike = likeCount/len(data)
    print(typeVal + '－「平均留言人數」：'+ str(avgComment) + '，「平均按讚人數」：' + str(avgLike))

my_calculate('熱門文章',"https://www.dcard.tw/_api/forums/job/posts?popular=true")
my_calculate('非熱門文章',"https://www.dcard.tw/_api/forums/job/posts?popular=false")
# Out:
# 熱門文章－「平均留言人數」：9.9，「平均按讚人數」：74.86666666666666
# 非熱門文章－「平均留言人數」：2.1，「平均按讚人數」：2.4
